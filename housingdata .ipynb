# %%
from google.colab import files
uploded=files.upload()
# Out:
#      <input type="file" id="files-ca7f9f41-1129-40fa-9e6a-2d4f2725f4b7" name="files[]" multiple disabled />
#      <output id="result-ca7f9f41-1129-40fa-9e6a-2d4f2725f4b7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving housingdata1.csv to housingdata1.csv

# %% [markdown]
# # Datta analysis and visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Read the csv file

# %%
df=pd.read_csv('housingdata1.csv')

# %% [markdown]
# # Preview data -- Which features are categorical vs numerical

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31     0  0.538  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07     0  0.469  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07     0  0.469  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18     0  0.458  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18     0  0.458  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 14 columns]

# %% [markdown]
# # What is the distribution of numerical feature values across the samples?

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS  ...           B       LSTAT        MEDV
# count  506.000000  506.000000  506.000000  ...  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779  ...  356.674032   12.653063   22.532806
# std      8.601545   23.322453    6.860353  ...   91.294864    7.141062    9.197104
# min      0.006320    0.000000    0.460000  ...    0.320000    1.730000    5.000000
# 25%      0.082045    0.000000    5.190000  ...  375.377500    6.950000   17.025000
# 50%      0.256510    0.000000    9.690000  ...  391.440000   11.360000   21.200000
# 75%      3.677082   12.500000   18.100000  ...  396.225000   16.955000   25.000000
# max     88.976200  100.000000   27.740000  ...  396.900000   37.970000   50.000000
#
# [8 rows x 14 columns]

# %% [markdown]
# # Which features contain blank, null or empty values?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null int64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(11), int64(3)
# memory usage: 55.4 KB

# %% [markdown]
# # to findout number of null values in Each column and suming their count

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.nunique()
# Out:
# CRIM       504
# ZN          26
# INDUS       76
# CHAS         2
# NOX         81
# RM         446
# AGE        356
# DIS        412
# RAD          9
# TAX         66
# PTRATIO     46
# B          357
# LSTAT      455
# MEDV       229
# dtype: int64

# %%
df.drop(['CHAS'],axis=1,inplace=True)
df.head()
# Out:
#       CRIM    ZN  INDUS    NOX     RM  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31  0.538  6.575  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07  0.469  6.421  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07  0.469  7.185  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18  0.458  6.998  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18  0.458  7.147  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 13 columns]

# %%
df.drop(['NOX'],axis=1,inplace=True)
df.head()
# Out:
#       CRIM    ZN  INDUS     RM   AGE  ...  TAX  PTRATIO       B  LSTAT  MEDV
# 0  0.00632  18.0   2.31  6.575  65.2  ...  296     15.3  396.90   4.98  24.0
# 1  0.02731   0.0   7.07  6.421  78.9  ...  242     17.8  396.90   9.14  21.6
# 2  0.02729   0.0   7.07  7.185  61.1  ...  242     17.8  392.83   4.03  34.7
# 3  0.03237   0.0   2.18  6.998  45.8  ...  222     18.7  394.63   2.94  33.4
# 4  0.06905   0.0   2.18  7.147  54.2  ...  222     18.7  396.90   5.33  36.2
#
# [5 rows x 12 columns]

# %% [markdown]
# # to display all the data in pairplot

# %%
sns.pairplot(df)

# %% [markdown]
# # to display all the data in heatmap

# %%
sns.heatmap(df.corr())

# %% [markdown]
# # get the average of  RM,LSTAT,PTRATIO

# %%
 df.groupby(['RM','LSTAT','PTRATIO']).mean()
# Out:
#                          CRIM    ZN  INDUS    AGE  ...  RAD  TAX       B  MEDV
# RM    LSTAT PTRATIO                                ...
# 3.561 7.12  20.2      4.55587   0.0  18.10   87.9  ...   24  666  354.70  27.5
# 3.863 13.33 20.2     13.52220   0.0  18.10  100.0  ...   24  666  131.42  23.1
# 4.138 23.34 20.2     20.71620   0.0  18.10  100.0  ...   24  666  370.22  11.9
#       37.97 20.2     18.49820   0.0  18.10  100.0  ...   24  666  396.90  13.8
# 4.368 30.63 20.2     20.08490   0.0  18.10   91.2  ...   24  666  285.83   8.8
# 4.519 36.98 20.2     45.74610   0.0  18.10  100.0  ...   24  666   88.27   7.0
# 4.628 34.37 20.2     18.81100   0.0  18.10  100.0  ...   24  666   28.79  17.9
# 4.652 28.28 20.2     24.39380   0.0  18.10  100.0  ...   24  666  396.90  10.5
# 4.880 30.62 20.2     14.33370   0.0  18.10  100.0  ...   24  666  372.92  10.2
# 4.903 29.29 14.7      2.77974   0.0  19.58   97.8  ...    5  403  396.90  11.8
# ...

# %% [markdown]
# # display the LSTAT data

# %%
sns.countplot(x='LSTAT',data=df,palette='coolwarm')

# %%
sns.jointplot(x='LSTAT',y='RM',data=df)

# %%
sns.jointplot(x='PTRATIO',y='RM',data=df)

# %%
sns.jointplot(x='PTRATIO',y='LSTAT',data=df)

# %%
sns.jointplot(x='TAX',y='LSTAT',data=df)

# %% [markdown]
# # display ZN data

# %%
sns.countplot(x='ZN',data=df,palette='coolwarm')

# %%
sns.jointplot(x='INDUS',y='ZN',data=df)

# %%
sns.jointplot(x='RAD',y='ZN',data=df)

# %%
sns.jointplot(x='B',y='ZN',data=df)

# %%
sns.jointplot(x='ZN',y='LSTAT',data=df)

# %%
sns.jointplot(x='CRIM',y='LSTAT',data=df)

# %% [markdown]
# # Let's define the Independet Variable: X and the Dependent Variable: y

# %%
d=df[['CRIM','ZN','INDUS','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT']]

# %%
X = d.iloc[:, :].values

# %%
X
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
g=df[['MEDV']]

# %%
y=g.iloc[:,:].values

# %%
y
# Out:
# array([[24. ],
#        [21.6],
#        [34.7],
#        [33.4],
#        [36.2],
#        [28.7],
#        [22.9],
#        [27.1],
#        [16.5],
#        [18.9],
#        [15. ],
#        [18.9],
#        [21.7],
#        [20.4],
#        [18.2],
#        [19.9],
#        [23.1],
#        [17.5],
#        [20.2],
#        [18.2],
#        [13.6],
#        [19.6],
#        [15.2],
#        [14.5],
#        [15.6],
#        [13.9],
#        [16.6],
#        [14.8],
#        [18.4],
#        [21. ],
#        [12.7],
#        [14.5],
#        [13.2],
#        [13.1],
#        [13.5],
#        [18.9],
#        [20. ],
#        [21. ],
#        [24.7],
#        [30.8],
#        [34.9],
#        [26.6],
#        [25.3],
#        [24.7],
#        [21.2],
#        [19.3],
#        [20. ],
#        [16.6],
#        [14.4],
#        [19.4],
#        [19.7],
#        [20.5],
#        [25. ],
#        [23.4],
#        [18.9],
#        [35.4],
#        [24.7],
#        [31.6],
# ...

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Importing the Keras libraries and packages

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

# %% [markdown]
# # Adding the input layer and the first hidden layer
# # Adding the second hidden layer
# # Adding the output layer
# # Compiling the ANN

# %%
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'linear'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'mse', metrics = ['mae'])

# %%
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 379/379 [==============================] - 2s 5ms/step - loss: 595.4674 - mean_absolute_error: 22.5867
# Epoch 2/100
# 379/379 [==============================] - 0s 180us/step - loss: 591.4333 - mean_absolute_error: 22.5018
# Epoch 3/100
# 379/379 [==============================] - 0s 181us/step - loss: 579.4293 - mean_absolute_error: 22.2456
# Epoch 4/100
# 379/379 [==============================] - 0s 173us/step - loss: 548.5495 - mean_absolute_error: 21.5937
# Epoch 5/100
# 379/379 [==============================] - 0s 177us/step - loss: 490.2502 - mean_absolute_error: 20.2902
# Epoch 6/100
# 379/379 [==============================] - 0s 173us/step - loss: 401.0771 - mean_absolute_error: 18.1515
# Epoch 7/100
# 379/379 [==============================] - 0s 178us/step - loss: 298.7404 - mean_absolute_error: 15.3113
# Epoch 8/100
# 379/379 [==============================] - 0s 183us/step - loss: 201.5136 - mean_absolute_error: 12.0902
# Epoch 9/100
# ...

# %% [markdown]
# # predctions

# %%
y_pred = classifier.predict(X_test)

# %%
y_pred
# Out:
# array([[25.428741],
#        [23.428394],
#        [26.915962],
#        [11.641305],
#        [19.84778 ],
#        [18.054369],
#        [20.398493],
#        [20.92629 ],
#        [13.662046],
#        [16.525505],
#        [ 4.014056],
#        [10.89244 ],
#        [17.611032],
#        [11.174893],
#        [40.308517],
#        [32.6261  ],
#        [20.307589],
#        [37.182526],
#        [32.967552],
#        [22.49416 ],
#        [25.272703],
#        [20.364765],
#        [18.871098],
#        [27.217249],
#        [21.563023],
#        [18.626146],
#        [15.632413],
#        [17.447727],
#        [42.319992],
#        [18.598392],
#        [16.587791],
#        [19.046951],
#        [16.00954 ],
#        [20.595793],
#        [28.734789],
#        [20.954794],
#        [ 8.813849],
#        [24.005459],
#        [14.643673],
#        [13.509984],
#        [26.726284],
#        [21.844069],
#        [21.544935],
#        [17.179127],
#        [25.788786],
# ...

# %%
from sklearn.metrics import r2_score
a= r2_score(y_test,y_pred)
a
# Out:
# 0.6919194511454777

# %% [markdown]
# # show the data

# %%
plt.scatter(y_test,y_pred)
